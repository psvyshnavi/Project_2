# %%
pip install -r install_deepface.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'install_deepface.txt'

# %%
pip install deepface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread(r'C:\Users\psvys\Downloads\.deepface\weights\famous.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()
#It's used to convert BGR image to RGB on the fly.

# %%
result=DeepFace.analyze(img1,actions=['gender'])
# Out:
# Action: gender: 100%|████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.18it/s]

# %%
print(result)
# Out:
# [{'gender': {'Woman': 89.6162211894989, 'Man': 10.38377359509468}, 'dominant_gender': 'Woman', 'region': {'x': 117, 'y': 42, 'w': 75, 'h': 75}}]

# %%
print(result[0]['dominant_gender'])
# Out:
# Woman
